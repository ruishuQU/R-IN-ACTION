# %%
# 4-1 创建leadership数据框
manager <- c(1,2,3,4,5)
data <- c("10/24/08","10/28/08","10/1/08","10/12/08","5/1/09")
country <- c("US","US","UK","UK","UK")
gender <- c("M","F","F","M","F")
age <- c(32,45,25,39,99)
q1 <- c(5,3,3,3,2)
q2 <- c(4,5,5,3,2)
q3 <- c(5,2,5,4,1)
q4 <- c(5,5,5,NA,2)
q5 <- c(5,5,2,NA,1)
leadership <- data.frame(manager,data,country,gender,age,
                        q1,q2,q3,q4,q5,stringsAsFactors = FALSE)
str(leadership)
# Out:
# 'data.frame':	5 obs. of  10 variables:
#  $ manager: num  1 2 3 4 5
#  $ data   : chr  "10/24/08" "10/28/08" "10/1/08" "10/12/08" ...
#  $ country: chr  "US" "US" "UK" "UK" ...
#  $ gender : chr  "M" "F" "F" "M" ...
#  $ age    : num  32 45 25 39 99
#  $ q1     : num  5 3 3 3 2
#  $ q2     : num  4 5 5 3 2
#  $ q3     : num  5 2 5 4 1
#  $ q4     : num  5 5 5 NA 2
#  $ q5     : num  5 5 2 NA 1

# %%
mydata <- data.frame(x1 = c(2,2,6,4),
                    x2 = c(3,4,2,8))
mydata$sumx <- mydata$x1 + mydata$x2
mydata$meanx <- (mydata$x1 + mydata$x2)/2

# %%
mydata <- data.frame(x1 = c(2,2,6,4),
                    x2 = c(3,4,2,8))
attach(mydata)
mydata$sumx <- x1 + x2
mydata$meanx <- (x1 + x2)/2
detach(mydata)
mydata
# Out:
# The following objects are masked from mydata (pos = 3):
#
#     x1, x2
#   x1 x2 sumx meanx
# 1 2  3   5   2.5
# 2 2  4   6   3.0
# 3 6  2   8   4.0
# 4 4  8  12   6.0

# %%
mydata <- transform(mydata,
                   sumx = x1 + x2,
                   meanx = (x1 + x2)/2)
mydata
# Out:
#   x1 x2 sumx meanx
# 1 2  3   5   2.5
# 2 2  4   6   3.0
# 3 6  2   8   4.0
# 4 4  8  12   6.0

# %%
leadership$age[leadership$age == 99]  <- NA
leadership$agecat[leadership$age > 75] <-"Elder"
leadership$agecat[leadership$age >= 55 & leadership$age <= 75] <- "Middle Aged"
leadership$agecat[leadership$age < 55] <- "Young"

# %%
# 代码改写为紧凑
leadership <- within(leadership,{
    agecat <- NA
    agecat[age > 75]   <- "Elder"
    agecat[age >= 55 & age <= 75] <- "Middle Aged"
    agecat[age < 55] <- "Young"
})

# %%
# 4.4 变量的重命名
fix(leadership)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
names(leadership)[2] <- "testDate"  # 修改第二列的列名

# %%
str(leadership)
# Out:
# 'data.frame':	5 obs. of  11 variables:
#  $ manager : num  1 2 3 4 5
#  $ testDate: chr  "10/24/08" "10/28/08" "10/1/08" "10/12/08" ...
#  $ country : chr  "US" "US" "UK" "UK" ...
#  $ gender  : chr  "M" "F" "F" "M" ...
#  $ age     : num  32 45 25 39 NA
#  $ q1      : num  5 3 3 3 2
#  $ q2      : num  4 5 5 3 2
#  $ q3      : num  5 2 5 4 1
#  $ q4      : num  5 5 5 NA 2
#  $ q5      : num  5 5 2 NA 1
#  $ agecat  : chr  "Young" "Young" "Young" "Young" ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
leadership
# Out:
#   manager testDate country gender age q1 q2 q3 q4 q5 agecat
# 1 1       10/24/08 US      M      32  5  4  5   5  5 Young
# 2 2       10/28/08 US      F      45  3  5  2   5  5 Young
# 3 3       10/1/08  UK      F      25  3  5  5   5  2 Young
# 4 4       10/12/08 UK      M      39  3  3  4  NA NA Young
# 5 5       5/1/09   UK      F      NA  2  2  1   2  1 NA

# %%
names(leadership)[6:10] <- c("item1","item2","item3","item4","item5")#修改变量名的方式，将第6到第10个变量名修改

# %%
str(leadership)
# Out:
# 'data.frame':	5 obs. of  11 variables:
#  $ manager : num  1 2 3 4 5
#  $ testDate: chr  "10/24/08" "10/28/08" "10/1/08" "10/12/08" ...
#  $ country : chr  "US" "US" "UK" "UK" ...
#  $ gender  : chr  "M" "F" "F" "M" ...
#  $ age     : num  32 45 25 39 NA
#  $ item1   : num  5 3 3 3 2
#  $ item2   : num  4 5 5 3 2
#  $ item3   : num  5 2 5 4 1
#  $ item4   : num  5 5 5 NA 2
#  $ item5   : num  5 5 2 NA 1
#  $ agecat  : chr  "Young" "Young" "Young" "Young" ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#install.packages("plyr")#使用plyr中的rename()函数
library(plyr)
