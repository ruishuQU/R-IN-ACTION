# %%
# 4-1 创建leadership数据框
manager <- c(1,2,3,4,5)
data <- c("10/24/08","10/28/08","10/1/08","10/12/08","5/1/09")
country <- c("US","US","UK","UK","UK")
gender <- c("M","F","F","M","F")
age <- c(32,45,25,39,99)
q1 <- c(5,3,3,3,2)
q2 <- c(4,5,5,3,2)
q3 <- c(5,2,5,4,1)
q4 <- c(5,5,5,NA,2)
q5 <- c(5,5,2,NA,1)
leadership <- data.frame(manager,data,country,gender,age,
                        q1,q2,q3,q4,q5,stringsAsFactors = FALSE)
str(leadership)
# Out:
# 'data.frame':	5 obs. of  10 variables:
#  $ manager: num  1 2 3 4 5
#  $ data   : chr  "10/24/08" "10/28/08" "10/1/08" "10/12/08" ...
#  $ country: chr  "US" "US" "UK" "UK" ...
#  $ gender : chr  "M" "F" "F" "M" ...
#  $ age    : num  32 45 25 39 99
#  $ q1     : num  5 3 3 3 2
#  $ q2     : num  4 5 5 3 2
#  $ q3     : num  5 2 5 4 1
#  $ q4     : num  5 5 5 NA 2
#  $ q5     : num  5 5 2 NA 1

# %%
mydata <- data.frame(x1 = c(2,2,6,4),
                    x2 = c(3,4,2,8))
mydata$sumx <- mydata$x1 + mydata$x2
mydata$meanx <- (mydata$x1 + mydata$x2)/2

# %%
mydata <- data.frame(x1 = c(2,2,6,4),
                    x2 = c(3,4,2,8))
attach(mydata)
mydata$sumx <- x1 + x2
mydata$meanx <- (x1 + x2)/2
detach(mydata)
mydata
# Out:
# The following objects are masked from mydata (pos = 3):
#
#     x1, x2
#   x1 x2 sumx meanx
# 1 2  3   5   2.5
# 2 2  4   6   3.0
# 3 6  2   8   4.0
# 4 4  8  12   6.0

# %%
mydata <- transform(mydata,
                   sumx = x1 + x2,
                   meanx = (x1 + x2)/2)
mydata
# Out:
#   x1 x2 sumx meanx
# 1 2  3   5   2.5
# 2 2  4   6   3.0
# 3 6  2   8   4.0
# 4 4  8  12   6.0

# %%
leadership$age[leadership$age == 99]  <- NA
leadership$agecat[leadership$age > 75] <-"Elder"
leadership$agecat[leadership$age >= 55 & leadership$age <= 75] <- "Middle Aged"
leadership$agecat[leadership$age < 55] <- "Young"

# %%
# 代码改写为紧凑
leadership <- within(leadership,{
    agecat <- NA
    agecat[age > 75]   <- "Elder"
    agecat[age >= 55 & age <= 75] <- "Middle Aged"
    agecat[age < 55] <- "Young"
})

# %%
# 4.4 变量的重命名
fix(leadership)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
names(leadership)[2] <- "testDate"  # 修改第二列的列名

# %%
str(leadership)
# Out:
# 'data.frame':	5 obs. of  10 variables:
#  $ managerID: num  1 2 3 4 5
#  $ testDate : chr  "10/24/08" "10/28/08" "10/1/08" "10/12/08" ...
#  $ country  : chr  "US" "US" "UK" "UK" ...
#  $ gender   : chr  "M" "F" "F" "M" ...
#  $ age      : num  32 45 25 39 99
#  $ q1       : num  5 3 3 3 2
#  $ q2       : num  4 5 5 3 2
#  $ q3       : num  5 2 5 4 1
#  $ q4       : num  5 5 5 NA 2
#  $ q5       : num  5 5 2 NA 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
leadership
# Out:
#   managerID testDate country gender age q1 q2 q3 q4 q5
# 1 1         10/24/08 US      M      32  5  4  5   5  5
# 2 2         10/28/08 US      F      45  3  5  2   5  5
# 3 3         10/1/08  UK      F      25  3  5  5   5  2
# 4 4         10/12/08 UK      M      39  3  3  4  NA NA
# 5 5         5/1/09   UK      F      99  2  2  1   2  1

# %%
names(leadership)[6:10] <- c("item1","item2","item3","item4","item5")#修改变量名的方式，将第6到第10个变量名修改

# %%
str(leadership)
# Out:
# 'data.frame':	5 obs. of  10 variables:
#  $ managerID: num  1 2 3 4 5
#  $ testDate : chr  "10/24/08" "10/28/08" "10/1/08" "10/12/08" ...
#  $ country  : chr  "US" "US" "UK" "UK" ...
#  $ gender   : chr  "M" "F" "F" "M" ...
#  $ age      : num  32 45 25 39 99
#  $ item1    : num  5 3 3 3 2
#  $ item2    : num  4 5 5 3 2
#  $ item3    : num  5 2 5 4 1
#  $ item4    : num  5 5 5 NA 2
#  $ item5    : num  5 5 2 NA 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#install.packages("plyr")#使用plyr中的rename()函数
library(plyr)

# %%
leadership <- rename(leadership,
                    c(manager = "managerID",date = "testDate")) #将新名字写在""中
leadership
# Out:
# The following `from` values were not present in `x`: date
#   managerID data     country gender age q1 q2 q3 q4 q5
# 1 1         10/24/08 US      M      32  5  4  5   5  5
# 2 2         10/28/08 US      F      45  3  5  2   5  5
# 3 3         10/1/08  UK      F      25  3  5  5   5  2
# 4 4         10/12/08 UK      M      39  3  3  4  NA NA
# 5 5         5/1/09   UK      F      99  2  2  1   2  1

# %%
str(leadership)
# Out:
# 'data.frame':	5 obs. of  10 variables:
#  $ managerID: num  1 2 3 4 5
#  $ testDate : chr  "10/24/08" "10/28/08" "10/1/08" "10/12/08" ...
#  $ country  : chr  "US" "US" "UK" "UK" ...
#  $ gender   : chr  "M" "F" "F" "M" ...
#  $ age      : num  32 45 25 39 99
#  $ item1    : num  5 3 3 3 2
#  $ item2    : num  4 5 5 3 2
#  $ item3    : num  5 2 5 4 1
#  $ item4    : num  5 5 5 NA 2
#  $ item5    : num  5 5 2 NA 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 4.5 缺失值
#缺失值以符号NA（Not Available）
# R 提供了识别缺失值的函数，is.na()来检测缺失值的存在
y <- c(1,2,3,NA)
is.na(y)#返回TRUE表示存在缺失值
# Out:
# [1] FALSE FALSE FALSE  TRUE

# %%
# 4-3 使用is,na()函数
is.na(leadership[,6:10])
#1.缺失值被认为是不可比较的
#2.R不讲无限的或者不可能出现的值标记为缺失值
# Out:
#      q1    q2    q3    q4    q5
# [1,] FALSE FALSE FALSE FALSE FALSE
# [2,] FALSE FALSE FALSE FALSE FALSE
# [3,] FALSE FALSE FALSE FALSE FALSE
# [4,] FALSE FALSE FALSE  TRUE  TRUE
# [5,] FALSE FALSE FALSE FALSE FALSE

# %%
# 4.5.1 重编码某些值为缺失值
leadership$age[leadership$age == 99] <- NA  #任何age中的等于99的值被重新编码为NA
str(leadership$age)
# Out:
#  num [1:5] 32 45 25 39 NA

# %%
# 4.5.2 在分析中排除缺失值
x <- c(1,2,NA,3)
y <- x[1]+x[2]+x[3]+x[4]# 因为存在缺失值，故相加后也为缺失值
z <- sum(x)
x
y
z
# Out:
# [1]  1  2 NA  3
# [1] NA
# [1] NA

# %%
x <- c(1,2,NA,3)
y <- sum(x,na.rm = TRUE)#移除缺失值，并使用剩余值进行计算
y
# Out:
# [1] 6

# %%
# 4-4 使用na.omit()删除不完整的观测
leadership# 含有缺失值的数据集
# Out:
#   managerID data     country gender age q1 q2 q3 q4 q5
# 1 1         10/24/08 US      M      32  5  4  5   5  5
# 2 2         10/28/08 US      F      45  3  5  2   5  5
# 3 3         10/1/08  UK      F      25  3  5  5   5  2
# 4 4         10/12/08 UK      M      39  3  3  4  NA NA
# 5 5         5/1/09   UK      F      NA  2  2  1   2  1

# %%
newdata <- na.omit(leadership)# 删除缺失值后留下的数据
newdata
# Out:
#   managerID data     country gender age q1 q2 q3 q4 q5
# 1 1         10/24/08 US      M      32  5  4  5  5  5
# 2 2         10/28/08 US      F      45  3  5  2  5  5
# 3 3         10/1/08  UK      F      25  3  5  5  5  2

# %%
# 4.6 日期值
mydates <- as.Date(c("2007-06-22","2004-02-13"))
mydates
# Out:
# [1] "2007-06-22" "2004-02-13"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
strDates <- c("01/05/1965", "08/16/1975")
dates <- as.Date(strDates, "%m/%d/%Y")#则使用mm/dd/yyyy的格式读取数据

# %% [markdown]
# myformat <- "%m/%d/%y"
#
# leadership$date <- as.Date(leadership$date, myformat)#使用指定格式读取字符型变量，并将其作为一个日期变量替换到数据框中

# %%
Sys.Date() #返回当前的日期
# Out:
# [1] "2022-04-28"

# %%
date()#返回当前的日期和时间
# Out:
# [1] "Thu Apr 28 19:10:52 2022"

# %%
#以使用函数format(x, format="output_format")来输出指定格式的日期值
today <- Sys.Date()
format(today, format="%B %d %Y")
# Out:
# [1] "四月 28 2022"

# %%
format(today, format="%A")
# Out:
# [1] "星期四"

# %%
format(today, format="%A %b %y")
# Out:
# [1] "星期四 4月 22"

# %%
# R的内部在存储日期时，
#是使用自1970年1月1日以来的天数表示的，
#更早的日期则表示为负数。

# %%
startdate <- as.Date("2004-02-13") 
enddate <- as.Date("2011-01-22") 
days <- enddate - startdate# 可以对日期进行算数运算
days
# Out:
# Time difference of 2535 days

# %%
# 以使用函数difftime()来计算时间间隔，并以星期、天、时、分、秒来表示
today <- Sys.Date() 
dob <- as.Date("1956-10-12")
difftime(today, dob, units="weeks")
# Out:
# Time difference of 3419.857 weeks

# %%
format(dob,format = "%A")
# Out:
# [1] "星期五"

# %%
# 4.6.1 将日期转换为字符型变量
# 函数as.character()可将日期值转换为字符型
strDates <- as.character(dates) 
strDates
# Out:
# [1] "1965-01-05" "1975-08-16"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 4-5 转换数据类型
a <- c(1,2,3) 
a
# Out:
# [1] 1 2 3

# %%
is.numeric(a)
# Out:
# [1] TRUE

# %%
 is.vector(a)
# Out:
# [1] TRUE

# %%
a <- as.character(a)
a
# Out:
# [1] "1" "2" "3"

# %%
is.numeric(a)
# Out:
# [1] FALSE

# %%
is.vector(a)
# Out:
# [1] TRUE

# %%
is.character(a)
# Out:
# [1] TRUE

# %%
# 4.8 数据排序
#使用order()函数对一个数据框进行排序。默认的排序顺序是升序。
#在排序变量的前边加一个减号即可得到降序的排序结果。
newdata <- leadership[order(leadership$age),]

# %%
attach(leadership)#创建了一个新的数据集
newdata <- leadership[order(gender, age),]#其中各行依经理人的年龄升序排序
detach(leadership)
newdata
# Out:
# The following objects are masked _by_ .GlobalEnv:
#
#     age, country, data, gender, q1, q2, q3, q4, q5
#   managerID data     country gender age q1 q2 q3 q4 q5
# 3 3         10/1/08  UK      F      25  3  5  5   5  2
# 2 2         10/28/08 US      F      45  3  5  2   5  5
# 5 5         5/1/09   UK      F      NA  2  2  1   2  1
# 1 1         10/24/08 US      M      32  5  4  5   5  5
# 4 4         10/12/08 UK      M      39  3  3  4  NA NA

# %%
attach(leadership)
newdata <-leadership[order(gender, -age),]#其中各行依经理人的年龄降序排序
detach(leadership) 
newdata
# Out:
# The following objects are masked _by_ .GlobalEnv:
#
#     age, country, data, gender, q1, q2, q3, q4, q5
#   managerID data     country gender age q1 q2 q3 q4 q5
# 5 5         5/1/09   UK      F      NA  2  2  1   2  1
# 2 2         10/28/08 US      F      45  3  5  2   5  5
# 3 3         10/1/08  UK      F      25  3  5  5   5  2
# 4 4         10/12/08 UK      M      39  3  3  4  NA NA
# 1 1         10/24/08 US      M      32  5  4  5   5  5

# %%
# 4.9 数据集的合并
#向数据框中添
#加列（变量）和行（观测）的方法。
# 4.9.1 向数据框添加列
#要横向合并两个数据框（数据集），请使用merge()函数
#total <- merge(dataframeA, dataframeB, by="ID")将dataframeA和dataframeB按照ID进行了合并

# %%
# 用cbind()进行横向合并
#这个函数将横向合并对象A和对象B。为了让它正常工作，每个对象必须拥有相同的行数，
#以同顺序排序。
#要纵向合并两个数据框（数据集），请使用rbind()函数

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 4.10 数据集取子集
# 4.10.1 选入（保留）变量
newdata <- leadership[, c(6:10)]
newdata
# Out:
#   q1 q2 q3 q4 q5
# 1 5  4  5   5  5
# 2 3  5  2   5  5
# 3 3  5  5   5  2
# 4 3  3  4  NA NA
# 5 2  2  1   2  1

# %%
myvars <- c("q1", "q2", "q3", "q4", "q5")
newdata <-leadership[myvars]# 选取myvars里面的数据组成一个新的数据集
newdata
# Out:
#   q1 q2 q3 q4 q5
# 1 5  4  5   5  5
# 2 3  5  2   5  5
# 3 3  5  5   5  2
# 4 3  3  4  NA NA
# 5 2  2  1   2  1
